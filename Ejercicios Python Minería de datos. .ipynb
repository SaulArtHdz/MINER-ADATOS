# %% [markdown]
# # TAREA - PÍA PÓSTER.
#
# Saúl Arath Hernández Hernández
# Alison Leonor Roldán Sánchez
# José Ignacio Contreras Ruíz
#
#
#
#
# ## MANIPULACIÓN DE DATOS.

# %% [markdown]
# * **Importar librerias y base de datos.**

# %%
import pandas as pd
import numpy as np

# %%
#Leyendo la base de datos.

data_frame = pd.read_csv("Stats_Prueba.csv")

# %% [markdown]
# * **Limpieza de datos.**

# %%
data_frame.shape # Número de filas y columnas.
# Out:
# (53798, 31)

# %%
data_frame.head() # Primeros cinco elementos de las columnas.
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...  2335      1989.0          Aug  Aug 26, 1989     6-5
# 1  624  1349  270  ...  1978      1990.0          Jul  Jul 15, 1990     6-3
# 2  627  1283  141  ...  1863      1996.0          Oct  Oct 30, 1996     6-6
# 3  685  1238   89  ...  1857      1994.0          Dec   Dec 6, 1994    6-11
# 4  546  1249  205  ...  1778      1998.0          Sep  Sep 19, 1998     6-2
#
# ...

# %%
data_frame.tail() # Últimos cinco elementos de las columnas.
# Out:
#       League       Season     Stage            Player Team  GP   MIN  FGM  \
# 53793    NBA  1999 - 2000  Playoffs       John Salley  LAL  18  78.0    5
# 53794    NBA  1999 - 2000  Playoffs     Muggsy Bogues  TOR   3  87.0    6
# 53795    NBA  1999 - 2000  Playoffs   Jerome Williams  DET   3  73.0    7
# 53796    NBA  1999 - 2000  Playoffs  Randy Livingston  PHX   7  63.0    6
# 53797    NBA  1999 - 2000  Playoffs     Doug Christie  TOR   3  61.0    3
#
#        FGA  3PM  ...  PTS  birth_year  birth_month    birth_date  height  \
# 53793   13    0  ...   17      1964.0          May  May 16, 1964    6-11
# 53794   21    3  ...   16      1965.0          Jan   Jan 9, 1965     5-3
# 53795   14    0  ...   15      1973.0          May  May 10, 1973     6-9
# 53796   27    2  ...   14      1975.0          Apr   Apr 2, 1975     6-4
# 53797   13    3  ...   12      1970.0          May   May 9, 1970     6-6
#
#        height_cm  weight  weight_kg    nationality                high_school
# ...

# %% [markdown]
# * **Desripción básica de columnas.**

# %%
data_frame.columns # Nombres de las columnas.
# Out:
# Index(['League', 'Season', 'Stage', 'Player', 'Team', 'GP', 'MIN', 'FGM',
#        'FGA', '3PM', '3PA', 'FTM', 'FTA', 'TOV', 'PF', 'ORB', 'DRB', 'REB',
#        'AST', 'STL', 'BLK', 'PTS', 'birth_year', 'birth_month', 'birth_date',
#        'height', 'height_cm', 'weight_lb', 'weight_kg', 'nationality',
#        'high_school'],
#       dtype='object')

# %%
data_frame.dtypes # Información sobre el tipo de dato.
# Out:
# League          object
# Season          object
# Stage           object
# Player          object
# Team            object
# GP               int64
# MIN            float64
# FGM              int64
# FGA              int64
# 3PM              int64
# 3PA              int64
# FTM              int64
# FTA              int64
# TOV              int64
# PF               int64
# ORB              int64
# DRB              int64
# REB              int64
# AST              int64
# STL              int64
# BLK              int64
# PTS              int64
# birth_year     float64
# birth_month     object
# birth_date      object
# height          object
# height_cm      float64
# weight_lb      float64
# weight_kg      float64
# nationality     object
# high_school     object
# dtype: object

# %% [markdown]
# Para nuestra base de datos, tenemos datos de tipo objeto, flotantes y enteros.
# Por el momento no nos vemos en la necesidad de cambiar nuestras variables ya que todas están bien definidas, por lo que las dejamos así para cuestión del ejercicio.

# %% [markdown]
# [Revisamos los datos nulos por columna](https://www.interactivechaos.com/python/scenario/calculo-del-numero-de-nan-por-columna-en-un-dataframe)

# %%
data_frame.isnull().any() # Revisamos que columnas contienen valores nulos.
# Out:
# League         False
# Season         False
# Stage          False
# Player         False
# Team            True
# GP             False
# MIN            False
# FGM            False
# FGA            False
# 3PM            False
# 3PA            False
# FTM            False
# FTA            False
# TOV            False
# PF             False
# ORB            False
# DRB            False
# REB            False
# AST            False
# STL            False
# BLK            False
# PTS            False
# birth_year      True
# birth_month     True
# birth_date      True
# height          True
# height_cm       True
# weight_lb       True
# weight_kg       True
# nationality     True
# high_school     True
# dtype: bool

# %%
data_frame.isnull().sum() # Calcula los datos nulos por columna.
# Out:
# League             0
# Season             0
# Stage              0
# Player             0
# Team              11
# GP                 0
# MIN                0
# FGM                0
# FGA                0
# 3PM                0
# 3PA                0
# FTM                0
# FTA                0
# TOV                0
# PF                 0
# ORB                0
# DRB                0
# REB                0
# AST                0
# STL                0
# BLK                0
# PTS                0
# birth_year       319
# birth_month      319
# birth_date       319
# height            74
# height_cm         74
# weight_lb       4566
# weight_kg       4566
# nationality        7
# high_school    30247
# dtype: int64

# %% [markdown]
# Por lo que para la columna de Team, birth_year, birth_month, birth_date, height, height_cm, weight_lb, weight_kg, nationality y high_school contamos con datos nulos NaN o None. Tomamos la decisión de borrar el dato de height ya que nos muestra la altura en pies pero la base de datos lo toma como un formato de fecha.

# %%
# El total de datos nulos en el data_frame es: 

data_frame.isnull().sum().sum()
# Out:
# 40502

# %%
data_frame.drop('height',axis = 1 )  #Como podemos ver, ya no se encuetra el valor de height en nuestra base de datos.
# Out:
#       League       Season           Stage                 Player Team  GP  \
# 0        NBA  2019 - 2020  Regular_Season           James Harden  HOU  68
# 1        NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66
# 2        NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70
# 3        NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63
# 4        NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60
# ...      ...          ...             ...                    ...  ...  ..
# 53793    NBA  1999 - 2000        Playoffs            John Salley  LAL  18
# 53794    NBA  1999 - 2000        Playoffs          Muggsy Bogues  TOR   3
# 53795    NBA  1999 - 2000        Playoffs        Jerome Williams  DET   3
# 53796    NBA  1999 - 2000        Playoffs       Randy Livingston  PHX   7
# 53797    NBA  1999 - 2000        Playoffs          Doug Christie  TOR   3
#
#           MIN  FGM   FGA  3PM  ...  BLK   PTS  birth_year  birth_month  \
# ...

# %% [markdown]
# * **Clasificación de los datos.**

# %%
data_frame.League.unique() # Creamos un clasificador en base a la columna ligas.
# Out:
# array(['NBA', 'Euroleague', 'Israeli-BSL', 'Argentinian-Liga-A',
#        'Australian-NBL', 'Austrian-A-Bundesliga', 'Balkan-BIL',
#        'Belarusian-BPL', 'Belgium-Scooore-League', 'Bosnian-BiH-Liga',
#        'Brazilian-NBB', 'British-BBL', 'Bulgarian-NBL', 'Canadian-NBL',
#        'Chinese-CBA', 'Croatian-A-1-Liga', 'Czech-NBL',
#        'Danish-Basketligaen', 'Estonian-Latvian-Basketball-League',
#        'Eurocup', 'FIBA-Europe-Cup', 'Finnish-Korisliiga',
#        'French-Jeep-Elite', 'Georgian-Super-Liga', 'German-BBL',
#        'Greek-HEBA-A1', 'Hungarian-NBIA', 'Italian-Lega-Basket-Serie-A',
#        'Japanese-BLeague', 'Kosovo-FBK', 'Lebanese-Division-A',
#        'Lithuanian-LKL', 'Luxembourg-Total-League',
#        'Macedonian-Superleague', 'Mexican-LNBP', 'Netherlands-DBL',
#        'New-Zealand-NBL', 'Norwegian-BLNO', 'Polish-TBL',
#        'Romanian-Divizia-A', 'Serbian-KLS', 'Slovakian-Extraliga',
#        'Slovenian-SKL', 'South-Korean-KBL', 'Spanish-ACB',
# ...

# %% [markdown]
# El paso siguiente es crear agrupaciones de datos por liga de basketball, para efectos del ejercicio, agrupamos las que tienen más relevancia para nosotros revisar sin tomar en cuenta la NBA tomando en cuenta nuestro objetivo principal.

# %%
#Agrupamos los valores de la liga NBA y los guardamos en un archivo csv.  #Para tener una base de datos solamente de la NBA.
clase_NBA= data_frame[data_frame['League']=='NBA']
clase_NBA.to_csv('Solo_NBA.csv', index=False)

# %%
#Agrupamos los valores de las ligas menos la NBA y las guardamos en un archivo csv. 
clase_NoNBA = data_frame[data_frame['League']!='NBA']

clase_NoNBA.to_csv('Solo_NoNBA.csv', index=False)

# %%
#Leyendo la base de datos de las ligas que no son la NBA para visualizar los que pertenecen a la última temporada reciente.

df_NoNBA = pd.read_csv("Solo_NoNBA.csv")

# %%
#Agrupamos los valores de las ligas menos la NBA de las últimas temporadas y las guardaamos en un archivo csv. 
clase_UltTemps = data_frame[data_frame['Season']=='2019 - 2020']

clase_UltTemps.to_csv('Solo_NoNBA_UltTemps.csv', index=False)

# %%
df_NoNBA_UltTemp = pd.read_csv("Solo_NoNBA_UltTemps.csv")

df_NoNBA_UltTemp
# Out:
#                      League       Season           Stage  \
# 0                       NBA  2019 - 2020  Regular_Season
# 1                       NBA  2019 - 2020  Regular_Season
# 2                       NBA  2019 - 2020  Regular_Season
# 3                       NBA  2019 - 2020  Regular_Season
# 4                       NBA  2019 - 2020  Regular_Season
# ...                     ...          ...             ...
# 7111  Ukrainian-Superleague  2019 - 2020   International
# 7112  Ukrainian-Superleague  2019 - 2020   International
# 7113  Ukrainian-Superleague  2019 - 2020   International
# 7114  Ukrainian-Superleague  2019 - 2020   International
# 7115  Ukrainian-Superleague  2019 - 2020   International
#
#                      Player  Team  GP     MIN  FGM   FGA  3PM  ...  BLK   PTS  \
# 0              James Harden   HOU  68  2482.6  672  1514  299  ...   60  2335
# 1            Damian Lillard   POR  66  2473.7  624  1349  270  ...   22  1978
# ...

# %% [markdown]
# #### Pregunta de interés y extras:

# %% [markdown]
# * ¿Para que me puede servir estas agrupaciones para la práctica siguiente?

# %% [markdown]
# R = Estas agrupaciones nos van a servir para una técnica de clasificación en la que podemos dinstiguir de las distintas agrupaciones que hay. A su vez, nos podrían servir para filtrar el problema y resolver objetivos secundarios por agrupaciones.

# %% [markdown]
# * Investigar los siguientes comandos: ?df.dropna() ?df.astype
#
# R= El comando [df.dropna()](https://www.interactivechaos.com/manual/tutorial-de-pandas/el-metodo-dropna#:~:text=El%20m%C3%A9todo%20dropna%20permite%2C%20de,dejar%20solo%20aquellos%20no%20nulos.&text=Vemos%20c%C3%B3mo%20ninguna%20fila%20se,ellas%20todos%20los%20elementos%20nulos.) permite, de una forma muy conveniente, filtrar los valores de una estructura de datos pandas para dejar solo aquellos no nulos. El comando [df.astype()](https://www.geeksforgeeks.org/python-pandas-dataframe-astype/) nos permite convertir a un tipo de categoria a otra en pandas.

# %% [markdown]
# ## VISUALIZACIÓN DE LOS DATOS

# %%
import numpy as np
import matplotlib as plt

# %% [markdown]
# Para esta sección trabajaremos sobre las ligas que no son la NBA dado el sesgo que este representa en los datos.

# %%
df_NoNBA
# Out:
#            League       Season          Stage             Player  Team  GP  \
# 0      Euroleague  2019 - 2020  International         Mike James  CSKA  28
# 1      Euroleague  2019 - 2020  International       Alexey Shved   KHI  26
# 2      Euroleague  2019 - 2020  International       Shane Larkin   EFE  25
# 3      Euroleague  2019 - 2020  International     Nikola Mirotic   FCB  28
# 4      Euroleague  2019 - 2020  International  Tornike Shengelia   CAJ  28
# ...           ...          ...            ...                ...   ...  ..
# 46303  Euroleague  2000 - 2001  International      Erik Cleymans   SPI  10
# 46304  Euroleague  2000 - 2001  International    Spencer Dunkley   LUG   9
# 46305  Euroleague  2000 - 2001  International    Claudio Pilutti   BOL  13
# 46306  Euroleague  2000 - 2001  International      Niklas Lutcke   FRA   8
# 46307  Euroleague  2000 - 2001  International      Martin Henlan    LT  10
#
# ...

# %% [markdown]
# * Estadística Básica.
# sum(): Suma todos los elementos de la columna seleccionada.
# mean(): Promedio.
# cumsum(): Suma acumulada de la columna fila por fila.
# describe(): Resumen estadístico de la columna.
# count(): Cuantos elementos no nulos hay en la columna.
# min(), max(): Minimo y máximo de una columna.
# median(), var(), std(): Mediana, varianza y desviación estandar.
# skew(): Valor de asimetría en los datos.
# kurt(): Característica de forma de su distribución de frecuencias/probabilidad.
# corr(): Correlación de los datos
# cov(): Covarianza de los datos.

# %%
df_NoNBA['FGM'].sum()  #Suma todos los elementos de la columna de tiros de campo hechos.
# Out:
# 97.95760991621319

# %%
df_NoNBA_UltTemp['FGM'].cumsum()  #Suma acumulada de los tiros de campo hechos de la última temporada 2019-2020
# Out:
# 0          672
# 1         1296
# 2         1923
# 3         2608
# 4         3154
#          ...
# 7111    504957
# 7112    504962
# 7113    504963
# 7114    504963
# 7115    504964
# Name: FGM, Length: 7116, dtype: int64

# %%
df_NoNBA_UltTemp['FGM'].mean()  #Promedio de los tiros de campo hechos de la última temporada 2019-2010 por jugador.
# Out:
# 70.96177627880832

# %%
df_NoNBA_UltTemp['MIN'].mean()  #Promedio de los minutos jugados de la última temporada 2019-2010 por jugador.
# Out:
# 466.311410905003

# %%
df_NoNBA_UltTemp.describe()  #Resumen estadístico de las columna.
# Out:
#                 GP          MIN          FGM          FGA          3PM  \
# count  7116.000000  7116.000000  7116.000000  7116.000000  7116.000000
# mean     21.569562   466.311411    70.961776   154.013491    20.693367
# std      11.225702   338.236226    67.578446   141.081920    24.304010
# min       1.000000    13.000000     0.000000     1.000000     0.000000
# 25%      15.000000   249.350000    29.000000    68.000000     4.000000
# 50%      20.000000   401.400000    56.000000   123.000000    14.000000
# 75%      25.000000   583.075000    91.000000   194.000000    29.000000
# max      74.000000  2556.400000   685.000000  1514.000000   299.000000
#
#                3PA          FTM          FTA          TOV           PF  ...  \
# count  7116.000000  7116.000000  7116.000000  7116.000000  7116.000000  ...
# mean     59.126476    33.113125    44.820405    28.962198    44.854272  ...
# std      63.933267    38.227455    48.446533    24.492478    29.125497  ...
# ...

# %%
df_NoNBA_UltTemp['Team'].count() 
#Cuantos elementos no nulos hay en la columna de equipo, como solo había 11 datos nulos
#suponemos que los 11 datos nulos se encuentran en los equipos de la última temporada.
# Out:
# 7105

# %%
df_NoNBA_UltTemp.median() # Mediana de las columnas de la última temporada 2019 - 2020
# Out:
# GP              20.0
# MIN            401.4
# FGM             56.0
# FGA            123.0
# 3PM             14.0
# 3PA             44.0
# FTM             23.0
# FTA             33.0
# TOV             23.0
# PF              40.0
# ORB             14.0
# DRB             44.0
# REB             59.0
# AST             28.0
# STL             13.0
# BLK              3.0
# PTS            154.0
# birth_year    1993.0
# height_cm      196.0
# weight         202.0
# weight_kg       92.0
# dtype: float64

# %%
df_NoNBA_UltTemp.var() #Varianza de las columnas de la última temporada 2019-2020
# Out:
# GP               126.016383
# MIN           114403.744769
# FGM             4566.846325
# FGA            19904.108040
# 3PM              590.684881
# 3PA             4087.462568
# FTM             1461.338290
# FTA             2347.066546
# TOV              599.881494
# PF               848.294572
# ORB              501.735054
# DRB             3255.086529
# REB             5817.505480
# AST             2433.790446
# STL              207.604011
# BLK              109.464396
# PTS            34930.390093
# birth_year        22.092432
# height_cm         74.568149
# weight           615.077504
# weight_kg        126.564208
# dtype: float64

# %%
df_NoNBA_UltTemp.skew()  #Valor de asimetría en las columnas de la última temporada 2019-2020.
# Out:
# GP            1.962631
# MIN           2.171905
# FGM           3.119906
# FGA           3.191169
# 3PM           3.078166
# 3PA           2.954276
# FTM           4.493193
# FTA           4.059665
# TOV           2.965047
# PF            1.934627
# ORB           3.086687
# DRB           3.449078
# REB           3.290863
# AST           3.826312
# STL           2.284895
# BLK           5.434993
# PTS           3.258884
# birth_year   -0.243226
# height_cm    -0.223976
# weight        0.385948
# weight_kg     0.382505
# dtype: float64

# %%
df_NoNBA_UltTemp.kurt() #Característica de forma de su distribución de frecuencias/probabilidad.
# Out:
# GP             5.061289
# MIN            7.002562
# FGM           15.581341
# FGA           16.270886
# 3PM           16.579784
# 3PA           15.665778
# FTM           38.104108
# FTA           30.776977
# TOV           16.955615
# PF             6.263387
# ORB           16.010199
# DRB           19.944558
# REB           18.469450
# AST           24.809526
# STL            8.488504
# BLK           51.451266
# PTS           17.720681
# birth_year    -0.243793
# height_cm     -0.258101
# weight        -0.063534
# weight_kg     -0.079848
# dtype: float64

# %%
df_NoNBA_UltTemp.corr()  #Correlación de los datos
# Out:
#                   GP       MIN       FGM       FGA       3PM       3PA  \
# GP          1.000000  0.856153  0.714562  0.736530  0.606336  0.631042
# MIN         0.856153  1.000000  0.909913  0.928703  0.747632  0.774263
# FGM         0.714562  0.909913  1.000000  0.980958  0.699505  0.713702
# FGA         0.736530  0.928703  0.980958  1.000000  0.777577  0.805890
# 3PM         0.606336  0.747632  0.699505  0.777577  1.000000  0.982550
# 3PA         0.631042  0.774263  0.713702  0.805890  0.982550  1.000000
# FTM         0.559437  0.765344  0.866238  0.855268  0.572522  0.598536
# FTA         0.567676  0.769227  0.871080  0.848737  0.516896  0.547252
# TOV         0.652618  0.840725  0.857282  0.871484  0.611606  0.652012
# PF          0.834412  0.859965  0.752300  0.753230  0.547581  0.575679
# ORB         0.527854  0.596448  0.629103  0.544428  0.114770  0.132426
# DRB         0.691756  0.831010  0.846566  0.806710  0.474079  0.498326
# ...

# %%
df_NoNBA_UltTemp.cov()  #Covarianza de los datos.
# Out:
#                      GP            MIN           FGM           FGA  \
# GP           126.016383    3250.759276    542.077712   1166.475239
# MIN         3250.759276  114403.744769  20798.324681  44316.780197
# FGM          542.077712   20798.324681   4566.846325   9352.544156
# FGA         1166.475239   44316.780197   9352.544156  19904.108040
# 3PM          165.426252    6145.902755   1148.886240   2666.198375
# 3PA          452.896190   16743.087046   3083.557470   7268.988455
# FTM          240.071188    9895.831499   2237.796876   4612.633751
# FTA          308.728587   12604.839815   2851.864252   5801.056815
# TOV          179.434324    6964.767965   1418.941211   3011.365232
# PF           272.814566    8471.776154   1480.719657   3095.081938
# ORB          132.728619    4518.867885    952.285402   1720.478452
# DRB          443.044779   16036.424658   3264.001133   6493.367233
# REB          575.773397   20555.292543   4216.286535   8213.845685
# ...

# %% [markdown]
# * Graficar datos univariantes.

# %%
df_NoNBA_UltTemp['League'].value_counts().plot.bar()  #Grafico de barras para los datos existentes por liga de la ult. temp.

# %%
(df_NoNBA_UltTemp['League'].value_counts() / len(df_NoNBA_UltTemp)).plot.bar()

# %% [markdown]
# De la gráfica anterior, podemos hacer la suposición que la liga Chinese - CBA cuenta con más jugadores que las demás ligas en la última temporada, por lo que podríamos decir que existe más atención sobre esta liga que las restantes para esta base de datos.

# %%
df_NoNBA_UltTemp['FGM'].value_counts().sort_index().plot.bar()  #Vemos la distribución de los tiros de campo hechos para la ult temporada.

# %% [markdown]
# * Gráficas de líneas.

# %%
df_NoNBA_UltTemp['FGM'].value_counts().sort_index().plot.line()

# %% [markdown]
# Si queremos rellenar los valores como una figura, remplazamos el line() por area().

# %% [markdown]
# * Histogramas.

# %%
df_NoNBA_UltTemp[df_NoNBA_UltTemp['GP'] < 80]['GP'].plot.hist()  #Distribución de los juegos jugados de la última temporada.

# %%
df_NoNBA_UltTemp['FGM'].plot.hist()  #Distribución de los goles de campos hecho de la última temporada.

# %% [markdown]
# * Gráficas bivariantes

# %%
df_NoNBA_UltTemp[df_NoNBA_UltTemp['GP'] < 80].plot.scatter(x='GP', y='FGM')  #Entre más juegos, más puntos anotados.

# %%
df_NoNBA_UltTemp[df_NoNBA_UltTemp['GP'] < 80].plot.hexbin(x='GP', y='FGM', gridsize=10) #La concentración se encuentra en menos juegos y menos puntos.

# %% [markdown]
# * Stacked Plots

# %%
df_NoNBA_UltTemp.head(10).plot.bar(stacked=True)  #No podemos usar esta gráfica ya que categoricamente, cada columna
                                                  #representa un dato distinto.

# %% [markdown]
# En lugar de la grafica de barras de matplotlib, seaborn tiene countplot.

# %%
import seaborn as sns

# %%
sns.distplot(df_NoNBA_UltTemp['MIN'], bins=10, kde=False)  #Distribución de los minutos de juego de los jugadores

# %% [markdown]
# Ahora tenemos los jointplots, que son como los scatter plots o los hexplots (graficas de coeficientes de correlacion), pero que muestran tambien histogramas de los datos en cada axis de la grafica.

# %%
sns.jointplot(x='GP', y='FGM', data=df_NoNBA_UltTemp[df_NoNBA_UltTemp['GP'] < 80]) #Correlación y histograma entre juegos y puntos anotados.

# %%
sns.jointplot(x='GP', y='FGM', data=df_NoNBA_UltTemp[df_NoNBA_UltTemp['GP'] < 80], kind='hex', 
              gridsize=20)

# %%
bp = df_NoNBA_UltTemp[df_NoNBA_UltTemp.variety.isin(df_NoNBA_UltTemp.variety.value_counts().head(5).index)]

sns.boxplot(
    x='MIN',
    y='PTS',
    data=bp
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-e5f0bf780991> in <module>
# ----> 1 bp = df_NoNBA_UltTemp[df_NoNBA_UltTemp.variety.isin(df_NoNBA_UltTemp.variety.value_counts().head(5).index)]
#       2
#       3 sns.boxplot(
#       4     x='MIN',
#       5     y='PTS',
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'variety'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-1976b80f787d> in <module>
#       1 import pandas as pd
# ----> 2 import pandas_profiling
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
sns.pairplot(df_NoNBA_UltTemp[['height_cm', 'weight_kg', 'BLK', 'STL']]) #Relación entre las variables

# %% [markdown]
# No agregué parte de multivariantes, en caso de verse necesario revisar.
